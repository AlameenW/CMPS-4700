# %% [markdown]
# # <center>Challenge 0<center>

# %% [markdown]
# <p>Team Name: Regular
# <p>Student Names: Alameen Adeku, Harper Laskie, Sirjana Acharya

# %% [markdown]
# ## Instructions
# Use generic coding style unless hard-coded values are really necessary.<br>
# Your code must be efficient and use self-explanatory naming.<br>
# Use appropriate Python library methods for each task instead of using loops.<br>
# Run your entire code and save. Then submit this <b>saved</b> copy.

# %% [markdown]
# ## Imports

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # PART I

# %% [markdown]
# ## Prepare Data

# %% [markdown]
# <b>A. Create a data set D with 100 data points with the following attributes (features) as such:</b><br>
# seed = 0<br>
# a1 is from a normal distribution N(mean=20,var=4)<br>
# a2 is from a uniform distribution U(min=14,max=26)<br>

# %%
np.random.seed(0)

a1 = np.random.normal(loc=20,scale=2, size = 100)
a2 = np.random.uniform(low=14, high=26, size=100)

D = pd.DataFrame({
    'a1': a1, 'a2': a2
})
print(D)
# Out:
#            a1         a2
# 0   23.528105  19.086261
# 1   20.800314  21.276719
# 2   21.957476  14.230318
# 3   24.481786  17.618898
# 4   23.735116  21.922082
# ..        ...        ...
# 95  21.413146  23.972581
# 96  20.021000  21.547782
# 97  23.571741  24.471808
# 98  20.253824  17.282504
# 99  20.803979  23.576562
#
# [100 rows x 2 columns]

# %% [markdown]
# x1 = 2*a1<br>
# x2 = normal distribution N(mean=40,var=4)<br>
# Pr(x1,x2,target) = {(x1, x2, 'P')}, data objects with class positive<br>
# P = Rotate(Pr,45), rotate Pr by 45 degrees in counter-clockwise<br>
# Nr = Shift(Pr,x1,20), shift in x1-dimension by 20 units towards right, data objects with class negative, where
# Nr(x1,x2,target) = {(x1_shifted, x2, 'N')}<br>
# N = Rotate(Nr,45), rotate Nr by 45 degrees in counter-clockwise<br>

# %%
pi = math.pi
def rotate_points(df, angle):
    x1_new, x2_new = [], []
    for _, row in df.iterrows():
        x1_new.append(row['x1']*math.cos(angle) - row['x2']*math.sin(angle))
        x2_new.append(row['x1']*math.sin(angle) + row['x2']*math.cos(angle))
    
    df = pd.DataFrame({'x1':x1_new, 'x2':x2_new})
    return df

x1 = [i*2 for i in a1]
x2 = np.random.normal(loc=40,scale=2, size = 100)
Pr_target = ['P' for i in range(len(x1))]

Pr = pd.DataFrame({'x1':x1, 'x2':x2, 'target': Pr_target})
# 45 degrees = pi/4 radians
P = rotate_points(Pr,pi/4)
P['target'] = Pr_target
print(P)
# Out:
#           x1         x2 target
# 0   5.912139  60.635391      P
# 1   1.684707  57.147466      P
# 2   2.070033  60.035088      P
# 3   6.502399  62.742550      P
# 4   8.154073  58.978973      P
# ..       ...        ...    ...
# 95  3.593740  56.971784      P
# 96 -0.366906  56.994846      P
# 97  6.455693  60.215258      P
# 98 -0.831285  58.117750      P
# 99  1.489785  57.352752      P
#
# [100 rows x 3 columns]

# %%
x1_shifted = [i+20 for i in x1]
print('Original x1:', x1)
print('Shifted x1:', x1_shifted)
Nr_target = ['N' for i in range(len(x1))]
Nr = pd.DataFrame({'x1':x1_shifted, 'x2':x2 ,'target': Nr_target})
N = rotate_points(Nr,pi/4)
N['target'] = Nr_target
print('N DataFrame:\n ', N)
# Out:
# Original x1: [47.05620938387066, 41.600628833468896, 43.91495193642296, 48.963572796805835, 47.47023196059987, 36.09088848049436, 43.80035367010236, 39.39457116680921, 39.58712459282577, 41.64239400775349, 40.576174284643514, 45.8170940278519, 43.04415090058797, 40.48670006597131, 41.7754529309817, 41.334697309497066, 45.97631629263042, 39.179366944936795, 41.252270806603605, 36.5836170427931, 29.788040736663685, 42.61447438176144, 43.457744795438025, 37.03133991837423, 49.07901849595043, 34.18253730160494, 40.18303406920578, 39.251264599896665, 46.13111685743383, 45.87743507960114, 40.61978970278766, 41.5126500784087, 36.448857009479546, 32.07681412710429, 38.60835140269539, 40.62539587641592, 44.921162722910886, 44.80951939513764, 38.45069273036819, 38.790788997698655, 35.80578813973163, 34.3199282512841, 33.17491923749995, 47.80310158092716, 37.96139127299339, 38.247702793555256, 34.98881855980029, 43.10996142332764, 33.5444086097682, 39.14903887914412, 36.4181337552253, 41.54760999143705, 37.95677944972451, 35.27747126351035, 39.88727108664538, 41.71332748212167, 40.26606888953267, 41.20988759095913, 37.46271162527614, 38.549035336051446, 37.3101582088962, 38.561787353837836, 36.74741487182219, 33.09486959067329, 40.70970456901501, 38.392876255166954, 33.47920661213582, 41.851129022103095, 36.37080654246703, 40.207781583184556, 42.91636224871015, 40.515931643029646, 44.5576027381732, 35.06069671858539, 41.60936656471019, 37.260759636238745, 36.51681140327247, 37.684601340942336, 38.75378987149051, 40.22466136891898, 35.33940063686657, 43.60330594781675, 41.86264975892184, 33.8550252548911, 45.9530087751824, 47.58355670412233, 44.715118284638606, 39.2803006567506, 35.71698951395783, 44.217806907724544, 38.38729221210728, 44.88978028152971, 40.83309991230744, 43.90655614593485, 41.425465588697605, 42.82629267276779, 40.042000082883284, 47.14348197562334, 40.50764837081448, 41.60795745377881]
# Shifted x1: [67.05620938387065, 61.600628833468896, 63.91495193642296, 68.96357279680583, 67.47023196059988, 56.09088848049436, 63.80035367010236, 59.39457116680921, 59.58712459282577, 61.64239400775349, 60.576174284643514, 65.81709402785191, 63.04415090058797, 60.48670006597131, 61.7754529309817, 61.334697309497066, 65.97631629263043, 59.179366944936795, 61.252270806603605, 56.5836170427931, 49.78804073666369, 62.61447438176144, 63.457744795438025, 57.03133991837423, 69.07901849595044, 54.18253730160494, 60.18303406920578, 59.251264599896665, 66.13111685743382, 65.87743507960114, 60.61978970278766, 61.5126500784087, 56.448857009479546, 52.07681412710429, 58.60835140269539, 60.62539587641592, 64.92116272291088, 64.80951939513764, 58.45069273036819, 58.790788997698655, 55.80578813973163, 54.3199282512841, 53.17491923749995, 67.80310158092716, 57.96139127299339, 58.247702793555256, 54.98881855980029, 63.10996142332764, 53.5444086097682, 59.14903887914412, 56.4181337552253, 61.54760999143705, 57.95677944972451, 55.27747126351035, 59.88727108664538, 61.71332748212167, 60.26606888953267, 61.20988759095913, 57.46271162527614, 58.549035336051446, 57.3101582088962, 58.561787353837836, 56.74741487182219, 53.09486959067329, 60.70970456901501, 58.392876255166954, 53.47920661213582, 61.851129022103095, 56.37080654246703, 60.207781583184556, 62.91636224871015, 60.515931643029646, 64.5576027381732, 55.06069671858539, 61.60936656471019, 57.260759636238745, 56.51681140327247, 57.684601340942336, 58.75378987149051, 60.22466136891898, 55.33940063686657, 63.60330594781675, 61.86264975892184, 53.8550252548911, 65.9530087751824, 67.58355670412233, 64.7151182846386, 59.2803006567506, 55.71698951395783, 64.21780690772454, 58.38729221210728, 64.88978028152971, 60.83309991230744, 63.90655614593485, 61.425465588697605, 62.82629267276779, 60.042000082883284, 67.14348197562333, 60.50764837081448, 61.60795745377881]
# N DataFrame:
#              x1         x2 target
# 0   20.054274  74.777527      N
# 1   15.826843  71.289602      N
# 2   16.212168  74.177223      N
# 3   20.644534  76.884685      N
# 4   22.296209  73.121108      N
# ..        ...        ...    ...
# 95  17.735875  71.113920      N
# 96  13.775230  71.136981      N
# 97  20.597829  74.357394      N
# 98  13.310851  72.259886      N
# 99  15.631921  71.494888      N
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Merge Data

# %% [markdown]
# Merge P and N into a single set PN.

# %%
PN = pd.concat([P,N], ignore_index=True)
print(PN)
# Out:
#             x1         x2 target
# 0     5.912139  60.635391      P
# 1     1.684707  57.147466      P
# 2     2.070033  60.035088      P
# 3     6.502399  62.742550      P
# 4     8.154073  58.978973      P
# ..         ...        ...    ...
# 195  17.735875  71.113920      N
# 196  13.775230  71.136981      N
# 197  20.597829  74.357394      N
# 198  13.310851  72.259886      N
# 199  15.631921  71.494888      N
#
# [200 rows x 3 columns]

# %% [markdown]
# # PART II

# %% [markdown]
# ## Visualize Data
# The axis scale should be the same. The class-P and -N data points will in red-circle and blue-triangle, respectively.

# %% [markdown]
# Plot Pr and P in the same figure on a separate sub-plots of 1 by 2:

# %% [markdown]
# Plot Nr and N in the same figure on a separate sub-plots of 1 by 2:

# %% [markdown]
# Plot {PN}:

# %% [markdown]
# # PART III

# %% [markdown]
# ## Simple Classifier

# %% [markdown]
# Classifier SimpleClassifier:
# Given data D(x1, x2, target),<br>
# If x1 + x2 > median, then predicted class:<br>
# ...    <b>N</b><br>
# Else<br>
# ...    <b>P</b>

# %% [markdown]
# Obtain predicted class labels of the dataset PN using SimpleClassifier:

# %% [markdown]
# Print output Y(x1,x2,True_Target, Predicted_Target)

# %% [markdown]
# Plot output Y. Use the same marker shape. Predicted Target colors: P in Red and N in blue. Zoom in to show miss classified data points as needed.

# %% [markdown]
# Obtain the Confusion Matrix and print:

# %% [markdown]
# Claculate the Performance Scores of Accuracy, Recall (Sensitivity), Specificity, F1-score. Plot as bar-chart:

# %% [markdown]
# ## <center> REFERENCES </center>
# List resources (book, internet page, etc.) that you used to complete this challenge.
